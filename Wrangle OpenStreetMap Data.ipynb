# %% [markdown]
# # **OpenStreeMap Data Wrangling with MongoDB  **#
#
# MapZen: https://mapzen.com/data/metro-extracts/metro/new-orleans_louisiana/
#
# I used the New Orleans, LA, USA area for this project.  The zipped file is included in the source under the map directory.

# %% [markdown]
# ## Load libraries needed for this project.

# %%
# load libraries
from collections import defaultdict
import codecs
import json
import re
import os
import pprint
import datetime as dt
import csv
import pandas as pd
import xml.etree.cElementTree as cET
import signal
import subprocess
from pymongo import MongoClient

#Load OSM file and path, in this case we are looking at New Orleans, LA, USA
filename = "new-orleans_louisiana.osm"
#Sample File to test with
#filename = "sample.osm"
path = "./map"
osmFile = os.path.join(path, filename)

# %% [markdown]
# ## Review Data
#
# We'll take a cursory look at the data by looking at the elements, users, and potential problems with the data.

# %%
#count the number of unique elements in our file to get a picture of the data structure
def count_tags(osm):
        tags = {}
        for event, elem in cET.iterparse(osm):
            if elem.tag in tags: 
                tags[elem.tag] += 1
            else:
                tags[elem.tag] = 1
        return tags
#execute count_tags on our osm file
tags = count_tags(osmFile)
#print the results
pprint.pprint(tags)
# Out:
# {'bounds': 1,
#  'member': 68224,
#  'nd': 7124566,
#  'node': 6413023,
#  'osm': 1,
#  'relation': 5963,
#  'tag': 1664974,
#  'way': 378498}

# %%
#get the users that have contributed to this OSM file
def get_users(osm):
    users = set()
    for _, element in cET.iterparse(osm):
        for e in element:
            if 'uid' in e.attrib:
                users.add(e.attrib['uid'])
    return users
users = get_users(osmFile)
len(users)
# Out:
# 899

# %%
lower_case = re.compile(r'^([a-z]|_)*$')
colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
badchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')

#search tags for three types of elements, ones that value values that are all lowercase and are valid, ones that are valid but have colons, and one that looks for bad or problem characters
def key_type(element, keys):
    if element.tag == "tag":
        for tag in element.iter('tag'):
            k = tag.get('k')
            if lower_case.search(k):
                keys['lower_case'] += 1
            elif colon.search(k):
                keys['colon'] += 1
            elif badchars.search(k):
                keys['badchars'] += 1
            else:
                keys['other'] += 1
    return keys


def search_keys(osm):
    keys = {"lower_case": 0, "colon": 0, "badchars": 0, "other": 0}
    for _, element in cET.iterparse(osm):
        keys = key_type(element, keys)

    return keys

keys = search_keys(osmFile)
pprint.pprint(keys)
# Out:
# {'badchars': 3, 'colon': 690509, 'lower_case': 659110, 'other': 315352}

# %% [markdown]
# ## Data Problems And Cleanup
#
# We need to clean up the address abbreviations so naming is consistent.

# %%
#Clean up street names so they all use the same abbreviation, print out the ones we updated.
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
expected = ["Avenue", "Boulevard", "Commons", "Court", "Drive", "Lane", "Parkway",
                         "Place", "Road", "Square", "Street", "Trail"]
mapping = {'Ave'  : 'Avenue',
           'Blvd' : 'Boulevard',
           'Dr'   : 'Drive',
           'Ln'   : 'Lane',
           'Pkwy' : 'Parkway',
           'Rd'   : 'Road',
           'Rd.'   : 'Road',
           'St'   : 'Street',
           'street' :"Street",
           'Ct'   : "Court",
           'Cir'  : "Circle",
           'Cr'   : "Court",
           'ave'  : 'Avenue',
           'Hwg'  : 'Highway',
           'Hwy'  : 'Highway',
           'Sq'   : "Square"}

def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)

def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    street_types = defaultdict(set)
    for event, elem in cET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])

    return street_types

def update_street_name(name, mapping, regex):
    m = regex.search(name)
    if m:
        street_type = m.group()
        if street_type in mapping:
            name = re.sub(regex, mapping[street_type], name)

    return name

def audit_streets(osmfile):
    #take inventory of street names
    streets = audit(osmfile)
    #loops through and show the ones that were updated
    street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)
    for street_type, ways in streets.iteritems():
        for name in ways:
            updated_name = update_street_name(name, mapping, street_type_re)
            if updated_name != name :
                print name, "=>", updated_name
                
#audit street names
audit_streets(osmFile)
# Out:
# Banks St => Banks Street
# Octavia St => Octavia Street
# S Broad St => S Broad Street
# Ponce De Leon St => Ponce De Leon Street
# Chartres St => Chartres Street
# Magazine Street;Magazine St => Magazine Street;Magazine Street
# East St => East Street
# E Rutland St => E Rutland Street
# North St => North Street
# Marais St => Marais Street
# Laurel St => Laurel Street
# N Rendon St => N Rendon Street
# Magazine St => Magazine Street
# Lasalle St => Lasalle Street
# Tchoupitoulas St => Tchoupitoulas Street
# South St => South Street
# Toulouse St => Toulouse Street
# Dauphine St => Dauphine Street
# Decatur St => Decatur Street
# 543 5th St => 543 5th Street
# Royal St => Royal Street
# Bourbon St => Bourbon Street
# Canal St => Canal Street
# South St Patrick St => South St Patrick Street
# Whitney St => Whitney Street
# S Dupre St => S Dupre Street
# Prytania St => Prytania Street
# Johnny Dufrene St => Johnny Dufrene Street
# Bayou Rd => Bayou Road
# West I-10 Service Rd => West I-10 Service Road
# Cobia Dr => Cobia Drive
# Acadia Dr => Acadia Drive
# Unity Dr => Unity Drive
# Keeneland Dr => Keeneland Drive
# Patterson Dr => Patterson Drive
# Galleria Blvd => Galleria Boulevard
# Citrus Blvd => Citrus Boulevard
# S Alex Plaisance Blvd => S Alex Plaisance Boulevard
# N Causeway Blvd => N Causeway Boulevard
# Shortcut Hwy => Shortcut Highway
# Woodland Hwy => Woodland Highway
# Jefferson Hwy => Jefferson Highway
# Napoleon Ave => Napoleon Avenue
# St. Claude Ave => St. Claude Avenue
# Rio Vista Ave => Rio Vista Avenue
# Hagan Ave => Hagan Avenue
# Franklin Ave => Franklin Avenue
# Esplanade Ave => Esplanade Avenue
# S Carrollton Ave => S Carrollton Avenue
# 1227 Tulane Ave => 1227 Tulane Avenue
# S Claiborne Ave => S Claiborne Avenue
# N Carrollton Ave => N Carrollton Avenue
# Severn Ave => Severn Avenue
# E 21st Ave => E 21st Avenue
# Orleans Ave => Orleans Avenue
# N Claiborne Ave => N Claiborne Avenue
# Elysian Fields Ave => Elysian Fields Avenue

# %% [markdown]
# ### Clean up invalid zipcodes

# %%
def audit_zipcode(invalid_zipcodes, zipcode):
    twoDigits = zipcode[0:2]

    if not twoDigits.isdigit():
        invalid_zipcodes[twoDigits].add(zipcode)

    elif twoDigits != 95:
        invalid_zipcodes[twoDigits].add(zipcode)

def is_zipcode(elem):
    return (elem.attrib['k'] == "addr:postcode")

def audit(osmfile):
    osm_file = open(osmfile, "r")
    invalid_zipcodes = defaultdict(set)
    for event, elem in cET.iterparse(osm_file, events=("start",)):

        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_zipcode(tag):
                    audit_zipcode(invalid_zipcodes,tag.attrib['v'])

    return invalid_zipcodes

def update_zips(zipcode):
    testNum = re.findall('[a-zA-Z]*', zipcode)
    if testNum:
        testNum = testNum[0]
    testNum.strip()
    if testNum == "LA":
        convertedZipcode = (re.findall(r'\d+', zipcode))
        if convertedZipcode:
            if convertedZipcode.__len__() == 2:
                return (re.findall(r'\d+', zipcode))[0] + "-" +(re.findall(r'\d+', zipcode))[1]
            else:
                return (re.findall(r'\d+', zipcode))[0]
    return zipcode


def audit_zips(osmFile):
    zipcodes = audit(osmFile)

    for street_type, ways in zipcodes.iteritems():
        for zipcode in ways:
            updated_zipcode = update_zips(zipcode)
            if zipcode != updated_zipcode :
                print zipcode, "=>", updated_zipcode
                
#audit zip codes
audit_zips(osmFile)
# Out:
# LA 70116 => 70116
# LA 70117 => 70117

# %% [markdown]
# ## Convert and import data into MongoDB

# %%
#Convert the file to json and save
CREATED = [ "version", "changeset", "timestamp", "user", "uid" ]

def shape_element(element) :
    node = {}
    if (element.tag == "node") or (element.tag == "way") :
        node["created"]={}
        node["pos"]=[]
        node["id"]=element.attrib["id"]
        node["type"]=element.tag

        try:
            node["pos"].append(float(element.attrib["lat"]))
            node["pos"].append(float(element.attrib["lon"]))
        except:
            pass
        for a in CREATED:

            if a in element.attrib:
                node["created"][a]=element.attrib[a]

        temp_address = {}
        
        if element.findall("./tag")!=[]:
            node["feature"]={}
            for tag in element.iter("tag"):
                if tag.attrib["k"] == "addr:street":
                    street = update_street_name(tag.attrib["v"], mapping, street_type_re)
                    if street:
                        temp_address["street"] = street
                elif tag.attrib["k"] == "addr:postcode":
                    zipcode = update_zips(tag.attrib["v"])
                    if zipcode:
                        temp_address["postcode"] = zipcode
                else:
                    node["feature"][tag.attrib["k"]]=tag.attrib["v"]

            if temp_address:
                node["address"] = temp_address
    return  node

def convert_file(file_in):

    file_out = "{0}.json".format(file_in)
    data = []
    with codecs.open(file_out, "w") as fo:
        for _, element in cET.iterparse(file_in):
            el = shape_element(element)
            if el:
                data.append(el)
                fo.write(json.dumps(el) + "\n")
    return data

convert_file(osmFile)
# Out:
# [{'created': {'changeset': '46303647',
#    'timestamp': '2017-02-22T11:24:34Z',
#    'uid': '4007051',
#    'user': 'upendrakarukonda',
#    'version': '15'},
#   'feature': {'ele': '2',
#    'is_in:continent': 'North America',
#    'is_in:country': 'United States',
#    'is_in:country_code': 'US',
#    'loc_name:vi': u'Ng\u1ecdc L\xe2n',
#    'name': 'New Orleans',
#    'name:ca': 'Nova Orleans',
#    'name:es': 'Nueva Orleans',
#    'name:fr': u'La Nouvelle-Orl\xe9ans',
#    'name:kn': u'\u0cb9\u0cca\u0cb8 \u0c92\u0cb0\u0ccd\u0cb2\u0cc0\u0ca8\u0ccd\u0cb8\u0ccd',
#    'name:ru': u'\u041d\u043e\u0432\u044b\u0439 \u041e\u0440\u043b\u0435\u0430\u043d',
#    'name:zh': u'\u65b0\u5965\u5c14\u826f',
#    'place': 'city',
#    'population': '354850',
#    'wikidata': 'Q34404',
#    'wikipedia': 'en:New Orleans'},
#   'id': '28110976',
#   'pos': [29.9499323, -90.0701156],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:09Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481154',
#   'pos': [29.997133, -90.138244],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481159',
#   'pos': [29.999402, -90.138114],
#   'type': 'node'},
#  {'created': {'changeset': '20134148',
#    'timestamp': '2014-01-22T02:00:27Z',
#    'uid': '1494110',
#    'user': 'KristenK',
#    'version': '3'},
#   'id': '115481162',
#   'pos': [30.000759, -90.1380628],
#   'type': 'node'},
#  {'created': {'changeset': '22808423',
#    'timestamp': '2014-06-08T12:05:07Z',
#    'uid': '8764',
#    'user': 'egore911',
#    'version': '5'},
#   'id': '115481165',
#   'pos': [30.0016773, -90.1380282],
#   'type': 'node'},
#  {'created': {'changeset': '20134148',
#    'timestamp': '2014-01-22T02:00:27Z',
#    'uid': '1494110',
#    'user': 'KristenK',
#    'version': '4'},
#   'id': '115481168',
#   'pos': [30.001987, -90.1379907],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481171',
#   'pos': [30.00427, -90.137863],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481174',
#   'pos': [30.006551, -90.137741],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481176',
#   'pos': [30.008832, -90.137626],
#   'type': 'node'},
#  {'created': {'changeset': '5998809',
#    'timestamp': '2010-10-10T05:17:49Z',
#    'uid': '142843',
#    'user': 'stumpydoo5',
#    'version': '3'},
#   'id': '115481179',
#   'pos': [30.0110982, -90.1375124],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481185',
#   'pos': [30.013381, -90.137397],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481188',
#   'pos': [30.013572, -90.13739],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481190',
#   'pos': [30.013727, -90.137382],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481193',
#   'pos': [30.013866, -90.137374],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:10Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481196',
#   'pos': [30.016019, -90.13726],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:21Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481198',
#   'pos': [30.018024, -90.137153],
#   'type': 'node'},
#  {'created': {'changeset': '24626075',
#    'timestamp': '2014-08-09T00:02:10Z',
#    'uid': '91499',
#    'user': 'paulmach',
#    'version': '3'},
#   'id': '115481208',
#   'pos': [30.0181059, -90.1371507],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481215',
#   'pos': [29.988019, -90.13874],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481217',
#   'pos': [29.990291, -90.138618],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481218',
#   'pos': [29.992624, -90.138488],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481219',
#   'pos': [29.994882, -90.138366],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481220',
#   'pos': [29.996406, -90.138282],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481228',
#   'pos': [29.875022, -90.122528],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481231',
#   'pos': [29.875045, -90.122642],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481234',
#   'pos': [29.875022, -90.122863],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481236',
#   'pos': [29.874944, -90.123008],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481238',
#   'pos': [29.874727, -90.123329],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481240',
#   'pos': [29.874675, -90.123374],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481248',
#   'pos': [29.972929, -90.18086],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481251',
#   'pos': [29.973522, -90.180747],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:22Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481254',
#   'pos': [29.974227, -90.18061],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481256',
#   'pos': [29.974899, -90.18048],
#   'type': 'node'},
#  {'created': {'changeset': '6719769',
#    'timestamp': '2010-12-20T20:36:45Z',
#    'uid': '41187',
#    'user': 'Matt Toups',
#    'version': '4'},
#   'id': '115481262',
#   'pos': [29.975561, -90.1802722],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481279',
#   'pos': [29.986635, -90.171562],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481282',
#   'pos': [29.987638, -90.171653],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481285',
#   'pos': [29.989406, -90.171821],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481295',
#   'pos': [29.983312, -90.207611],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481300',
#   'pos': [29.982866, -90.208343],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481308',
#   'pos': [29.982967, -90.208488],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481309',
#   'pos': [29.983051, -90.209106],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481311',
#   'pos': [29.983066, -90.209327],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481313',
#   'pos': [29.983097, -90.209838],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481315',
#   'pos': [29.983112, -90.210227],
#   'type': 'node'},
#  {'created': {'changeset': '17361410',
#    'timestamp': '2013-08-15T16:20:11Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115481323',
#   'pos': [30.0020401, -90.252641],
#   'type': 'node'},
#  {'created': {'changeset': '17361410',
#    'timestamp': '2013-08-15T16:20:11Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115481325',
#   'pos': [30.0042513, -90.2528785],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481327',
#   'pos': [30.006475, -90.253082],
#   'type': 'node'},
#  {'created': {'changeset': '17361410',
#    'timestamp': '2013-08-15T16:20:11Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '4'},
#   'id': '115481333',
#   'pos': [30.0066186, -90.2531052],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:11Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481336',
#   'pos': [30.008274, -90.253257],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481346',
#   'pos': [30.001625, -90.252586],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481349',
#   'pos': [29.999946, -90.252769],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481352',
#   'pos': [29.998392, -90.252883],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481360',
#   'pos': [30.009391, -90.253341],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481362',
#   'pos': [30.01128, -90.253555],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481364',
#   'pos': [30.013067, -90.253746],
#   'type': 'node'},
#  {'created': {'changeset': '29105395',
#    'timestamp': '2015-02-26T01:08:58Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115481370',
#   'pos': [29.8518682, -90.0788263],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481372',
#   'pos': [29.852214, -90.078948],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481373',
#   'pos': [29.853052, -90.079231],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481376',
#   'pos': [29.855257, -90.080017],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481378',
#   'pos': [29.855726, -90.080154],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:23Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481381',
#   'pos': [29.855834, -90.080146],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481383',
#   'pos': [29.856056, -90.08007],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481385',
#   'pos': [29.85655, -90.079833],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481388',
#   'pos': [29.857257, -90.079643],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481390',
#   'pos': [29.857559, -90.079627],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481392',
#   'pos': [29.857931, -90.079643],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481395',
#   'pos': [29.858715, -90.079818],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481398',
#   'pos': [29.858785, -90.079811],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481414',
#   'pos': [29.866064, -90.047065],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481417',
#   'pos': [29.866083, -90.04705],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481420',
#   'pos': [29.86634, -90.047004],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481423',
#   'pos': [29.86749, -90.046928],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481426',
#   'pos': [29.867679, -90.046897],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481429',
#   'pos': [29.867803, -90.046859],
#   'type': 'node'},
#  {'created': {'changeset': '25754524',
#    'timestamp': '2014-09-29T19:55:47Z',
#    'uid': '1240849',
#    'user': 'ediyes',
#    'version': '3'},
#   'id': '115481441',
#   'pos': [29.840389, -90.1169148],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481443',
#   'pos': [29.840568, -90.115333],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481444',
#   'pos': [29.840646, -90.114997],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481447',
#   'pos': [29.840679, -90.114761],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481450',
#   'pos': [29.840703, -90.114387],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481453',
#   'pos': [29.840707, -90.114341],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481456',
#   'pos': [29.840896, -90.112701],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481466',
#   'pos': [29.971574, -90.239364],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:12Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481469',
#   'pos': [29.971359, -90.239631],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481472',
#   'pos': [29.971323, -90.239723],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481475',
#   'pos': [29.971267, -90.239784],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481478',
#   'pos': [29.971157, -90.239791],
#   'type': 'node'},
#  {'created': {'changeset': '15664315',
#    'timestamp': '2013-04-09T10:18:16Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '115481489',
#   'pos': [29.894447, -90.0100011],
#   'type': 'node'},
#  {'created': {'changeset': '15664315',
#    'timestamp': '2013-04-09T10:18:16Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '115481493',
#   'pos': [29.8945093, -90.0113511],
#   'type': 'node'},
#  {'created': {'changeset': '15664315',
#    'timestamp': '2013-04-09T10:18:16Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '115481496',
#   'pos': [29.8945312, -90.0118244],
#   'type': 'node'},
#  {'created': {'changeset': '15664315',
#    'timestamp': '2013-04-09T10:18:16Z',
#    'uid': '42429',
#    'user': '42429',
#    'version': '3'},
#   'id': '115481499',
#   'pos': [29.8945707, -90.0126798],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481502',
#   'pos': [29.894626, -90.013877],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481513',
#   'pos': [29.867387, -90.03115],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481515',
#   'pos': [29.867372, -90.030952],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481517',
#   'pos': [29.867427, -90.030693],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481522',
#   'pos': [29.867527, -90.029846],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481525',
#   'pos': [29.867513, -90.029731],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481534',
#   'pos': [29.979537, -90.199691],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481537',
#   'pos': [29.979215, -90.200851],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481540',
#   'pos': [29.979057, -90.201408],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481543',
#   'pos': [29.978887, -90.202018],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481545',
#   'pos': [29.978706, -90.202697],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481547',
#   'pos': [29.978698, -90.202926],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481549',
#   'pos': [29.978723, -90.203392],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481551',
#   'pos': [29.978771, -90.204231],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481553',
#   'pos': [29.978811, -90.204917],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481555',
#   'pos': [29.978826, -90.205062],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:24Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481557',
#   'pos': [29.978866, -90.206031],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481559',
#   'pos': [29.978895, -90.206428],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481561',
#   'pos': [29.978919, -90.206527],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481563',
#   'pos': [29.978971, -90.206611],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481565',
#   'pos': [29.978984, -90.206634],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481577',
#   'pos': [30.013343, -90.136459],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481579',
#   'pos': [30.013414, -90.138435],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481582',
#   'pos': [30.013458, -90.139587],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481585',
#   'pos': [30.013511, -90.140769],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481587',
#   'pos': [30.013566, -90.141952],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481590',
#   'pos': [30.013576, -90.142173],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481592',
#   'pos': [30.013629, -90.143379],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481593',
#   'pos': [30.013668, -90.144332],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481594',
#   'pos': [30.013639, -90.144569],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:13Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481596',
#   'pos': [30.013572, -90.14495],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481597',
#   'pos': [30.013559, -90.145042],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481598',
#   'pos': [30.013547, -90.145118],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481600',
#   'pos': [30.013511, -90.145454],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481603',
#   'pos': [30.013509, -90.145606],
#   'type': 'node'},
#  {'created': {'changeset': '5998809',
#    'timestamp': '2010-10-10T05:32:32Z',
#    'uid': '142843',
#    'user': 'stumpydoo5',
#    'version': '4'},
#   'id': '115481606',
#   'pos': [30.013529, -90.1465192],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481609',
#   'pos': [30.013576, -90.147392],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:16Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481612',
#   'pos': [30.0136418, -90.1483182],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481615',
#   'pos': [30.0136575, -90.1486067],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481617',
#   'pos': [30.013662, -90.148957],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481618',
#   'pos': [30.013674, -90.1490023],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481620',
#   'pos': [30.013675, -90.149185],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481622',
#   'pos': [30.013721, -90.150032],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481624',
#   'pos': [30.013752, -90.1502709],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481626',
#   'pos': [30.0137627, -90.150415],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481629',
#   'pos': [30.013769, -90.1505357],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '4'},
#   'id': '115481632',
#   'pos': [30.0137773, -90.1506576],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:14Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481635',
#   'pos': [30.013771, -90.15084],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481638',
#   'pos': [30.013809, -90.151657],
#   'type': 'node'},
#  {'created': {'changeset': '5998704',
#    'timestamp': '2010-10-10T04:46:12Z',
#    'uid': '142843',
#    'user': 'stumpydoo5',
#    'version': '4'},
#   'id': '115481642',
#   'pos': [30.0138638, -90.1531683],
#   'type': 'node'},
#  {'created': {'changeset': '33245759',
#    'timestamp': '2015-08-10T17:47:12Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '4'},
#   'id': '115481645',
#   'pos': [30.0139184, -90.1546248],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481648',
#   'pos': [30.013929, -90.154968],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481650',
#   'pos': [30.01395, -90.156158],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481652',
#   'pos': [30.013952, -90.156204],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481655',
#   'pos': [30.014007, -90.157165],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481658',
#   'pos': [30.014066, -90.157844],
#   'type': 'node'},
#  {'created': {'changeset': '5998809',
#    'timestamp': '2010-10-10T05:24:38Z',
#    'uid': '142843',
#    'user': 'stumpydoo5',
#    'version': '5'},
#   'id': '115481661',
#   'pos': [30.014104, -90.1589719],
#   'type': 'node'},
#  {'created': {'changeset': '5998704',
#    'timestamp': '2010-10-10T04:46:21Z',
#    'uid': '142843',
#    'user': 'stumpydoo5',
#    'version': '4'},
#   'id': '115481664',
#   'pos': [30.0141142, -90.159132],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481666',
#   'pos': [30.014154, -90.159744],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481669',
#   'pos': [30.014183, -90.159851],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481672',
#   'pos': [30.014358, -90.160224],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481674',
#   'pos': [30.014404, -90.160453],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481677',
#   'pos': [30.014421, -90.160636],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481679',
#   'pos': [30.014478, -90.161682],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481681',
#   'pos': [30.014577, -90.163177],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481683',
#   'pos': [30.014625, -90.163841],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481685',
#   'pos': [30.014657, -90.164314],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481686',
#   'pos': [30.014673, -90.164611],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481688',
#   'pos': [30.014865, -90.167633],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481690',
#   'pos': [30.0149, -90.168205],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481692',
#   'pos': [30.014919, -90.168464],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:25Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481695',
#   'pos': [30.014955, -90.168924],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481698',
#   'pos': [30.014965, -90.169052],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481699',
#   'pos': [30.015033, -90.170112],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481700',
#   'pos': [30.01509, -90.171035],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481701',
#   'pos': [30.015155, -90.171997],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481704',
#   'pos': [30.015161, -90.17208],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481706',
#   'pos': [30.01519, -90.172546],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481709',
#   'pos': [30.015205, -90.172782],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481712',
#   'pos': [30.015256, -90.173606],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481716',
#   'pos': [30.015354, -90.175155],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481718',
#   'pos': [30.015384, -90.175674],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481720',
#   'pos': [30.015548, -90.178207],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:15Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481722',
#   'pos': [30.015586, -90.178787],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481723',
#   'pos': [30.015644, -90.179519],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481724',
#   'pos': [30.015655, -90.179664],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481741',
#   'pos': [29.906908, -90.022239],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481744',
#   'pos': [29.906959, -90.023101],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481746',
#   'pos': [29.907011, -90.023941],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481749',
#   'pos': [29.907022, -90.024391],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481752',
#   'pos': [29.906991, -90.024604],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481755',
#   'pos': [29.906858, -90.025001],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481758',
#   'pos': [29.906663, -90.02552],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481760',
#   'pos': [29.90648, -90.026206],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481762',
#   'pos': [29.906452, -90.026481],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481764',
#   'pos': [29.906394, -90.026817],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481766',
#   'pos': [29.906343, -90.026985],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481768',
#   'pos': [29.90628, -90.027084],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481771',
#   'pos': [29.906064, -90.027275],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481773',
#   'pos': [29.905803, -90.02732],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481776',
#   'pos': [29.905117, -90.027351],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481779',
#   'pos': [29.90455, -90.027351],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481782',
#   'pos': [29.903781, -90.027412],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481783',
#   'pos': [29.903017, -90.027481],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481785',
#   'pos': [29.901962, -90.027526],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481787',
#   'pos': [29.901176, -90.027587],
#   'type': 'node'},
#  {'created': {'changeset': '48236210',
#    'timestamp': '2017-04-28T18:33:13Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115481789',
#   'pos': [29.9010324, -90.0276051],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481790',
#   'pos': [29.900783, -90.027603],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481794',
#   'pos': [29.900266, -90.027648],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481797',
#   'pos': [29.898792, -90.028358],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481800',
#   'pos': [29.898372, -90.028541],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:26Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481802',
#   'pos': [29.898038, -90.028633],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481805',
#   'pos': [29.896104, -90.028747],
#   'type': 'node'},
#  {'created': {'changeset': '48236210',
#    'timestamp': '2017-04-28T18:33:13Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115481809',
#   'pos': [29.8954366, -90.0288105],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:16Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481842',
#   'pos': [29.982107, -90.269859],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481844',
#   'pos': [29.982294, -90.269836],
#   'type': 'node'},
#  {'created': {'changeset': '21266936',
#    'timestamp': '2014-03-23T15:56:34Z',
#    'uid': '1679807',
#    'user': 'Cato_d_Ae',
#    'version': '4'},
#   'id': '115481847',
#   'pos': [29.9823496, -90.269797],
#   'type': 'node'},
#  {'created': {'changeset': '21266936',
#    'timestamp': '2014-03-23T15:56:34Z',
#    'uid': '1679807',
#    'user': 'Cato_d_Ae',
#    'version': '4'},
#   'id': '115481850',
#   'pos': [29.9823965, -90.2697131],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481854',
#   'pos': [29.982549, -90.269111],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481857',
#   'pos': [29.982658, -90.268653],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481865',
#   'pos': [29.982868, -90.267768],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481867',
#   'pos': [29.982862, -90.267677],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481870',
#   'pos': [29.982837, -90.267631],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:27Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115481877',
#   'pos': [29.982337, -90.267379],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:17Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115481883',
#   'pos': [29.854902, -90.118728],
#   'type': 'node'},
# ...
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484699',
#   'pos': [29.8766081, -90.0483412],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484701',
#   'pos': [29.876805, -90.0478241],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484702',
#   'pos': [29.8768834, -90.0477984],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484706',
#   'pos': [29.8770872, -90.0478012],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484707',
#   'pos': [29.8773043, -90.0479252],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484709',
#   'pos': [29.877086, -90.048408],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484713',
#   'pos': [29.8759767, -90.0482857],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484715',
#   'pos': [29.8764488, -90.0484548],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484718',
#   'pos': [29.8766126, -90.0478167],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484721',
#   'pos': [29.8761612, -90.0477686],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484725',
#   'pos': [29.8760858, -90.0477726],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484727',
#   'pos': [29.8759544, -90.0481948],
#   'type': 'node'},
#  {'created': {'changeset': '28515178',
#    'timestamp': '2015-01-30T23:58:13Z',
#    'uid': '1494110',
#    'user': 'KristenK',
#    'version': '4'},
#   'id': '115484736',
#   'pos': [29.921107, -90.0347644],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484737',
#   'pos': [29.920879, -90.034446],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484738',
#   'pos': [29.920749, -90.03421],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:48Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484740',
#   'pos': [29.920568, -90.033996],
#   'type': 'node'},
#  {'created': {'changeset': '28515178',
#    'timestamp': '2015-01-30T23:58:13Z',
#    'uid': '1494110',
#    'user': 'KristenK',
#    'version': '4'},
#   'id': '115484742',
#   'pos': [29.9203966, -90.0338415],
#   'type': 'node'},
#  {'created': {'changeset': '28515178',
#    'timestamp': '2015-01-30T23:58:13Z',
#    'uid': '1494110',
#    'user': 'KristenK',
#    'version': '4'},
#   'id': '115484744',
#   'pos': [29.9203023, -90.0337021],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115484750',
#   'pos': [30.0138, -90.1503233],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115484752',
#   'pos': [30.0138427, -90.1503664],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115484755',
#   'pos': [30.0139014, -90.1503695],
#   'type': 'node'},
#  {'created': {'changeset': '48208334',
#    'timestamp': '2017-04-27T20:34:17Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115484757',
#   'pos': [30.0139574, -90.1503433],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484760',
#   'pos': [30.01399, -90.150299],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484763',
#   'pos': [30.014032, -90.150199],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484771',
#   'pos': [29.87416, -90.046333],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484774',
#   'pos': [29.874794, -90.046501],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484777',
#   'pos': [29.8749904, -90.0456539],
#   'type': 'node'},
#  {'created': {'changeset': '29090963',
#    'timestamp': '2015-02-25T12:53:15Z',
#    'uid': '22925',
#    'user': 'ELadner',
#    'version': '3'},
#   'id': '115484780',
#   'pos': [29.8746501, -90.045556],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484793',
#   'pos': [29.855371, -90.059585],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484795',
#   'pos': [29.855266, -90.059837],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484797',
#   'pos': [29.855125, -90.060371],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484798',
#   'pos': [29.854801, -90.06166],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484804',
#   'pos': [29.91994, -90.043395],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484816',
#   'pos': [29.919965, -90.044181],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484823',
#   'pos': [29.855625, -90.060546],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484829',
#   'pos': [29.929697, -90.179008],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484831',
#   'pos': [29.930046, -90.17855],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484833',
#   'pos': [29.929924, -90.178237],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:44Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484835',
#   'pos': [29.929935, -90.178207],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:49Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484843',
#   'pos': [29.930398, -90.1781],
#   'type': 'node'},
#  {'created': {'changeset': '32657236',
#    'timestamp': '2015-07-15T17:16:35Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115484853',
#   'pos': [29.8560543, -90.1116522],
#   'type': 'node'},
#  {'created': {'changeset': '32657236',
#    'timestamp': '2015-07-15T17:16:35Z',
#    'uid': '360392',
#    'user': 'maxerickson',
#    'version': '3'},
#   'id': '115484857',
#   'pos': [29.8557133, -90.1116139],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484868',
#   'pos': [29.661901, -90.101706],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484871',
#   'pos': [29.661901, -90.101737],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484873',
#   'pos': [29.66242, -90.101699],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484876',
#   'pos': [29.663434, -90.1017674],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484880',
#   'pos': [29.6641826, -90.1017516],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484885',
#   'pos': [29.6644629, -90.1017854],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484888',
#   'pos': [29.6646647, -90.1018034],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484890',
#   'pos': [29.6649391, -90.1018959],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484892',
#   'pos': [29.6658641, -90.1019252],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484894',
#   'pos': [29.6686427, -90.1019044],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484896',
#   'pos': [29.6693635, -90.1019426],
#   'type': 'node'},
#  {'created': {'changeset': '26261152',
#    'timestamp': '2014-10-22T18:07:09Z',
#    'uid': '436419',
#    'user': 'wvdp',
#    'version': '3'},
#   'id': '115484899',
#   'pos': [29.6694556, -90.1019742],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484907',
#   'pos': [29.669507, -90.103706],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484910',
#   'pos': [29.669521, -90.105087],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484913',
#   'pos': [29.669504, -90.105697],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '3'},
#   'id': '115484936',
#   'pos': [29.902206, -90.043395],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484939',
#   'pos': [29.902236, -90.043243],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484942',
#   'pos': [29.902256, -90.042579],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484944',
#   'pos': [29.902322, -90.042213],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484946',
#   'pos': [29.902334, -90.042076],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484949',
#   'pos': [29.902294, -90.041717],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484951',
#   'pos': [29.902256, -90.041404],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484954',
#   'pos': [29.902236, -90.041236],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484956',
#   'pos': [29.902219, -90.040809],
#   'type': 'node'},
#  {'created': {'changeset': '3115631',
#    'timestamp': '2009-11-14T18:21:50Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484958',
#   'pos': [29.902173, -90.039939],
#   'type': 'node'},
#  {'created': {'changeset': '2204087',
#    'timestamp': '2009-08-19T19:12:45Z',
#    'uid': '147510',
#    'user': 'woodpeck_fixbot',
#    'version': '2'},
#   'id': '115484961',
#   'pos': [29.904094, -90.039825],
#   'type': 'node'},
#  {'created': {'changeset': '33245759',
#    'timestamp': '2015-08-10T17:47:12Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '5'},
#   'id': '115484972',
#   'pos': [29.9941447, -90.1554811],
#   'type': 'node'},
#  {'created': {'changeset': '33245759',
#    'timestamp': '2015-08-10T17:47:12Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '4'},
#   'id': '115484975',
#   'pos': [29.9943182, -90.1554475],
#   'type': 'node'},
#  {'created': {'changeset': '33245759',
#    'timestamp': '2015-08-10T17:47:12Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '4'},
#   'id': '115484977',
#   'pos': [29.9944017, -90.1554251],
#   'type': 'node'},
#  {'created': {'changeset': '33245759',
#    'timestamp': '2015-08-10T17:47:12Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '4'},
#   'id': '115484979',
#   'pos': [29.9946181, -90.1553579],
#   'type': 'node'},
#  {'created': {'changeset': '33245759',
#    'timestamp': '2015-08-10T17:47:12Z',
#    'uid': '94578',
#    'user': 'andygol',
#    'version': '4'},
#   'id': '115484981',
#   'pos': [29.994762, -90.1552684],
#   'type': 'node'},
#  ...]

# %%
#connect to mongo db
def connectToMongo() :
    pro = subprocess.Popen('mongod', preexec_fn = os.setsid)
    db_name = 'udacity_p3'
    mongo = MongoClient('localhost:27017')
    return mongo[db_name]

db = connectToMongo()

# %%
#Import our file into mongodb
db_name = 'udacity_p3'
collection = 'data'
json_file = osmFile + '.json'

mongoimport_cmd = 'mongoimport -h 127.0.0.1:27017 ' + \
                  '--db ' + db_name + \
                  ' --collection ' + collection + \
                  ' --file ' + json_file

# Before importing, drop collection if it is already running 
if collection in db.collection_names():
    print 'Dropping collection: ' + collection
    db[collection].drop()
    
# Execute the command
print 'Executing: ' + mongoimport_cmd
subprocess.call(mongoimport_cmd.split())
# Out:
# Dropping collection: data
# Executing: mongoimport -h 127.0.0.1:27017 --db udacity_p3 --collection data --file ./map/new-orleans_louisiana.osm.json
# 0

# %% [markdown]
# ## Load DB object for querying
#
# Load the db object for querying and explore the data

# %%
new_orleans_la_data = db[collection]

# %% [markdown]
# ### Get size of the original OSM file and the new JSON file

# %%
print 'The original OSM file is {} MB'.format(os.path.getsize(osmFile)/1.0e6) # convert from bytes to megabytes
print 'The JSON file is {} MB'.format(os.path.getsize(osmFile + ".json")/1.0e6) # convert from bytes to megabytes
# Out:
# The original OSM file is 1278.919201 MB
# The JSON file is 1388.497993 MB

# %% [markdown]
# ### Number of documents

# %%
new_orleans_la_data.find().count()
# Out:
# 6791521

# %% [markdown]
# ### Number of unique users

# %%
len(new_orleans_la_data.distinct('created.user'))
# Out:
# 885

# %% [markdown]
# ### Number of nodes and ways

# %%
print "Number of nodes:",new_orleans_la_data.find({'type':'node'}).count()
print "Number of ways:",new_orleans_la_data.find({'type':'way'}).count()
# Out:
# Number of nodes: 6413023
# Number of ways: 378498

# %% [markdown]
# ### Top 10 Contributors to this data

# %%
result = new_orleans_la_data.aggregate( [
                                        { "$group" : {"_id" : "$created.user", 
                                        "count" : { "$sum" : 1} } },
                                        { "$sort" : {"count" : -1} }, 
                                        { "$limit" : 10 } ] )

print(list(result))
# Out:
# [{u'count': 3441210, u'_id': u'Matt Toups'}, {u'count': 1226743, u'_id': u'ELadner'}, {u'count': 769110, u'_id': u'wvdp'}, {u'count': 348774, u'_id': u'coleman_nolaimport'}, {u'count': 250871, u'_id': u'ELadnerImp'}, {u'count': 212231, u'_id': u'woodpeck_fixbot'}, {u'count': 53381, u'_id': u'Matt Toups_nolaimport'}, {u'count': 38526, u'_id': u'Minh Nguyen_nolaimport'}, {u'count': 36321, u'_id': u'ceseifert_nolaimport'}, {u'count': 25930, u'_id': u'Maarten Deen'}]

# %% [markdown]
# ### Top 10 Amenities

# %%
amenities=new_orleans_la_data.aggregate([{"$match":{"feature.amenity":{"$exists":1}}},
                       {"$group":{"_id":"$feature.amenity","count":{"$sum":1}}},
                       {"$sort":{"count":-1}},
                       {"$limit":10}
                      ])

for result in amenities:
    print(result)
# Out:
# {u'count': 1132, u'_id': u'place_of_worship'}
# {u'count': 846, u'_id': u'school'}
# {u'count': 558, u'_id': u'parking'}
# {u'count': 408, u'_id': u'restaurant'}
# {u'count': 182, u'_id': u'grave_yard'}
# {u'count': 180, u'_id': u'fast_food'}
# {u'count': 167, u'_id': u'kindergarten'}
# {u'count': 154, u'_id': u'fire_station'}
# {u'count': 143, u'_id': u'fuel'}
# {u'count': 106, u'_id': u'cafe'}

# %% [markdown]
# ### Top Religion

# %%
religion=new_orleans_la_data.aggregate([{"$match":{"feature.amenity":"place_of_worship"}},
                       {"$group":{"_id":"$feature.religion","count":{"$sum":1}}},
                       {"$sort":{"count":-1}},
                       {"$limit":1}
                      ])
for result in religion:
    print result
# Out:
# {u'count': 1084, u'_id': u'christian'}

# %% [markdown]
# ### Most common types of cuisine

# %%
restaurants=new_orleans_la_data.aggregate([{"$match":{"feature.amenity":"restaurant"}},
                       {"$group":{"_id":"$feature.cuisine","count":{"$sum":1}}},
                       {"$sort":{"count":-1}},
                       {"$limit":10}
                      ])
for result in restaurants:
    print(result)
# Out:
# {u'count': 236, u'_id': None}
# {u'count': 22, u'_id': u'regional'}
# {u'count': 16, u'_id': u'mexican'}
# {u'count': 15, u'_id': u'pizza'}
# {u'count': 13, u'_id': u'american'}
# {u'count': 8, u'_id': u'vietnamese'}
# {u'count': 8, u'_id': u'italian'}
# {u'count': 8, u'_id': u'chinese'}
# {u'count': 8, u'_id': u'seafood'}
# {u'count': 6, u'_id': u'japanese'}

# %% [markdown]
# ### Most common types of fast food

# %%
fast_food=new_orleans_la_data.aggregate([{"$match":{"feature.amenity":"fast_food"}},
                       {"$group":{"_id":"$feature.cuisine","count":{"$sum":1}}},
                       {"$sort":{"count":-1}},
                       {"$limit":10}
                      ])
for result in fast_food:
    print(result)
# Out:
# {u'count': 81, u'_id': None}
# {u'count': 43, u'_id': u'burger'}
# {u'count': 16, u'_id': u'sandwich'}
# {u'count': 12, u'_id': u'chicken'}
# {u'count': 8, u'_id': u'american'}
# {u'count': 6, u'_id': u'pizza'}
# {u'count': 4, u'_id': u'mexican'}
# {u'count': 2, u'_id': u'ice_cream'}
# {u'count': 1, u'_id': u'seafood'}
# {u'count': 1, u'_id': u'sushi'}

# %% [markdown]
# ### Top 10 Gas Stations

# %%
def get_gas_stations(data):
    gas_stations=data.aggregate([{"$match":{"feature.amenity":"fuel"}},
                       {"$group":{"_id":"$feature.name","count":{"$sum":1}}},
                       {"$sort":{"count":-1}},
                       {"$limit":10}
                      ])
    for result in gas_stations:
        print(result)
        
get_gas_stations(new_orleans_la_data)
# Out:
# {u'count': 81, u'_id': None}
# {u'count': 17, u'_id': u'Shell'}
# {u'count': 8, u'_id': u'Chevron'}
# {u'count': 4, u'_id': u'Exxon'}
# {u'count': 3, u'_id': u'Racetrack'}
# {u'count': 2, u'_id': u'Circle K'}
# {u'count': 1, u'_id': u'Kangaroo'}
# {u'count': 1, u'_id': u'Circle K Shell'}
# {u'count': 1, u'_id': u'Cheap Smokes'}
# {u'count': 1, u'_id': u'Interstate Fuel'}

# %% [markdown]
# ## Improvements
#
# One way to improve the data is to get more people involved in collecting and verifying the data.  My recommendation is to create a mobile application that can interact and engage with people from their smart devices.
#
# I would use react native to build this app.  React Native allows you build apps in javascript that can compile into both Android and iOS applications.   This ability is beneficial so that one person doesn't have to learn two distinct programming languages, or does have to hire extra people to build 2 separate apps.  It also will cut down on time spent on maintenance and upgrades. React Native also has a geolocation feature that will allow us to know the users position which will be vital in tracking this information.
#
# When the user is stationary for a while, the app should prompt the user to enter information about their current location.  If it is a location that has been previously entered, it could prompt to verify the information.  The should be asked for the name of the location, as well as details such as type of location and address.   We can prompt for further information based on the type of location being entered.
#
# To provide better and more information, we could also tie into the Google Maps API.  We can use the latitude and longitude from our geolocation package to pull data from google.  It would be possible that in many instances a user could just be prompted to confirm information instead of having to enter it.  This would make for a much better experience and the ease of use should mean more interactions with users.
#
# To increase user engagement, we will need to incentivize our users through gamification.  I found a great resource (listed below) that listed the benefits of a bage based reward system in elearning.  I also think about the Achievement system in a game such as World of Warcraft.  These systems create a competitive environment for even trivial tasks.  It can reward the users with recognition via leaderboards and also help give them goals to work for.  Some ideas would be badges for entering 10, 25, 50, and 100 (to start) locations.
#
#
# https://facebook.github.io/react-native/
# https://facebook.github.io/react-native/docs/geolocation.html
# https://enterprise.google.com/maps/products/mapsapi.html
# https://elearningindustry.com/notable-benefits-using-badge-based-elearning-reward-system
# http://www.wowhead.com/achievement-guides

# %% [markdown]
# ## Anticipated Issues
#
# There are downsides to my proposal above.
#
# 1.  Building an app will cost time and mooney regardless of the technology used.  Apple and Google both charge fees to considered an official developer and publish apps to their respective stores.  Someone will need to learn react native and build the application (time) or hire someone to do it (money).
#
# 2.  Depending on users to enter data can easily lead to unreliable and conflicting data.  We would need a process in place to validate the data to make sure we have the most accurate data available published.  This would be another good use of the Google Maps API.
#
# 3.  Google Maps would be a great tool to integrate, however, it could become pricey.  I think our app would be free to use, which would start us at the standard plan.  However, you get a limited amount of API calls for free.  As the popularity of the app rises, the more this will cost.  Also, integrating and maintaining that integration with a 3rd party api will consume a lot of time.  If someone is hired to do this, it will also increase the cost monetarily.
#
# 4.  Gamification will also cost time and money.  The badges will require design and graphic work.  We would want these to look good and professional.  Integrating them into the app and adding the badge system will increase the complexity of the code.  That will be more time in implementation, maintenance, and testing.
#
# https://enterprise.google.com/maps/pricing/#compare-editions
